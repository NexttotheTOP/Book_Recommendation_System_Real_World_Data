# %%
liked_books = ["25545994", "8835305", "83880", "29495703", "32737635"]

# %%
# !head book_id_map.csv
# Out:
# book_id_csv,book_id
# 0,34684622
# 1,34536488
# 2,34017076
# 3,71730
# 4,30422361
# 5,33503613
# 6,33517540
# 7,34467031
# 8,6383669

# %%
# Making a dictionary with all the csv_id's, which are the key id's of our interaction file 
# and the values will be the id's of the file we just worked with 

csv_book_mapping = {}  # dictionary 
with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",") # reads every line of the file, then splits the line at the comma en assigns the first part to csv_id and the second part(book_id) to book_id
        csv_book_mapping[csv_id] = book_id

# %%
len(csv_book_mapping)
# Out:
# 2360651

# %%
# !head goodreads_interactions.csv
# Out:
# user_id,book_id,is_read,rating,is_reviewed
# 0,948,1,5,0
# 0,947,1,5,1
# 0,946,1,5,0
# 0,945,1,5,0
# 0,944,1,5,0
# 0,943,1,5,0
# 0,942,1,5,0
# 0,941,1,5,0
# 0,940,1,5,0

# %% [markdown]
# # Finding users who liked the same books

# %%
# Making a set with all the users that have read the same books as us and rated the book 4 or higher 

overlap_users = set() # list that can only contain unique values, no duplicates 

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in overlap_users:
            continue

        try:
            rating = int(rating)
        except ValueError:
            continue
        
        book_id = csv_book_mapping[csv_id]
        
        if book_id in liked_books and rating >= 4:
                overlap_users.add(user_id)

# %% [markdown]
# # Finding what books those users liked

# %%
rec_lines = []

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in overlap_users:
            book_id = csv_book_mapping[csv_id]
            rec_lines.append([user_id, book_id, rating])

# %%
len(overlap_users)
# Out:
# 355

# %%
len(rec_lines)
# Out:
# 333106

# %%
# Turning our recommendations into a pd dataframe

import pandas as pd

recs = pd.DataFrame(rec_lines, columns=["user_id", "book_id", "rating"])
recs["book_id"] = recs["book_id"].astype(str)

# %%
recs
# Out:
#        user_id   book_id rating
# 0          321     48855      5
# 1          321      2203      5
# 2          321   9418327      4
# 3          321  11230081      5
# 4          321    252577      4
# ...        ...       ...    ...
# 333101  863653  27824826      5
# 333102  863653  23280208      4
# 333103  863653  29095428      4
# 333104  863653  15753740      5
# 333105  863653  33898874      4
#
# [333106 rows x 3 columns]

# %% [markdown]
# # Finding the Top Recommendations

# %%
# Counting up how many tyimes each book occurs and showing the most commen ones (finding top recommendations)

top_recs = recs["book_id"].value_counts().head(10)

# Taking/showing the index 

top_recs = top_recs.index.values

# %%
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str) # converting our titles into text rather then numerical values

# %%
books_titles.head()
# Out:
#    book_id                                              title  ratings  \
# 0  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1  6066819                               Best Friends Forever    51184
# 2   287141                      The Aeneid for Boys and Girls       46
# 3  6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4   287149                               The Devil's Notebook      986
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/7327624-th...
# 1  https://www.goodreads.com/book/show/6066819-be...
# 2  https://www.goodreads.com/book/show/287141.The...
# 3  https://www.goodreads.com/book/show/6066812-al...
# 4  https://www.goodreads.com/book/show/287149.The...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1304100136m...
# 1  https://s.gr-assets.com/assets/nophoto/book/11...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1316637798m...
# 4  https://images.gr-assets.com/books/1328768789m...
#
#                                           mod_title
# 0    the unschooled wizard sun wolf and starhawk 12
# 1                              best friends forever
# 2                     the aeneid for boys and girls
# 3  alls fairy in love and war avalon web of magic 8
# 4                               the devils notebook

# %%
# checking which books are in our top recommendations

books_titles[books_titles["book_id"].isin(top_recs)]
# Out:
#           book_id                                              title  ratings  \
# 284473    2767052            The Hunger Games (The Hunger Games, #1)  4899965
# 436303   32737635                  The Most Dangerous Place on Earth     4063
# 463463       4671                                   The Great Gatsby  2758812
# 482663   26893819                                          The Girls    84357
# 790927       2657                              To Kill a Mockingbird  3255518
# 878151   18143977                        All the Light We Cannot See   498685
# 878545          3  Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 973220   19486412                                    Big Little Lies   335079
# 1091642  22557272                              The Girl on the Train  1076144
# 1095301  11870085                             The Fault in Our Stars  2429317
#
#                                                        url  \
# 284473   https://www.goodreads.com/book/show/2767052-th...
# 436303   https://www.goodreads.com/book/show/32737635-t...
# 463463   https://www.goodreads.com/book/show/4671.The_G...
# 482663   https://www.goodreads.com/book/show/26893819-t...
# 790927   https://www.goodreads.com/book/show/2657.To_Ki...
# 878151   https://www.goodreads.com/book/show/18143977-a...
# 878545   https://www.goodreads.com/book/show/3.Harry_Po...
# 973220   https://www.goodreads.com/book/show/19486412-b...
# 1091642  https://www.goodreads.com/book/show/22557272-t...
# 1095301  https://www.goodreads.com/book/show/11870085-t...
#
#                                                cover_image  \
# 284473   https://images.gr-assets.com/books/1447303603m...
# 436303   https://images.gr-assets.com/books/1477347638m...
# 463463   https://images.gr-assets.com/books/1490528560m...
# 482663   https://images.gr-assets.com/books/1492065338m...
# 790927   https://images.gr-assets.com/books/1361975680m...
# 878151   https://images.gr-assets.com/books/1451445646m...
# 878545   https://images.gr-assets.com/books/1474154022m...
# 973220   https://images.gr-assets.com/books/1492239430m...
# 1091642  https://images.gr-assets.com/books/1490903702m...
# 1095301  https://images.gr-assets.com/books/1360206420m...
#
#                                                  mod_title
# 284473                 the hunger games the hunger games 1
# 436303                   the most dangerous place on earth
# 463463                                    the great gatsby
# 482663                                           the girls
# 790927                               to kill a mockingbird
# 878151                         all the light we cannot see
# 878545   harry potter and the sorcerers stone harry pot...
# 973220                                     big little lies
# 1091642                              the girl on the train
# 1095301                             the fault in our stars

# %%
top_recs
# Out:
# array(['32737635', '22557272', '11870085', '2767052', '26893819',
#        '19486412', '18143977', '4671', '3', '2657'], dtype=object)

# %%
# Checking how many times a specific book is recommended 

all_recs = recs["book_id"].value_counts()

# %%
all_recs
# Out:
# book_id
# 32737635    332
# 22557272    248
# 11870085    218
# 2767052     211
# 26893819    206
#            ...
# 22859574      1
# 444734        1
# 23507708      1
# 25005110      1
# 27037166      1
# Name: count, Length: 124934, dtype: int64

# %%
# Adding a frame with index to our output 

all_recs = all_recs.to_frame().reset_index()

# %%
all_recs
# Out:
#          book_id  count
# 0       32737635    332
# 1       22557272    248
# 2       11870085    218
# 3        2767052    211
# 4       26893819    206
# ...          ...    ...
# 124929  22859574      1
# 124930    444734      1
# 124931  23507708      1
# 124932  25005110      1
# 124933  27037166      1
#
# [124934 rows x 2 columns]

# %%
# Merging our recommendations and their counting values together with our dataframe containing the books information 

all_recs = all_recs.merge(books_titles, how="inner", on="book_id")

# %%
all_recs
# Out:
#          book_id  count                                              title  \
# 0       32737635    332                  The Most Dangerous Place on Earth
# 1       22557272    248                              The Girl on the Train
# 2       11870085    218                             The Fault in Our Stars
# 3        2767052    211            The Hunger Games (The Hunger Games, #1)
# 4       26893819    206                                          The Girls
# ...          ...    ...                                                ...
# 116927  22859574      1                       The Year My Mother Came Back
# 116928    444734      1                                  Later, at the Bar
# 116929  23507708      1  All Dogs Go to Kevin: Everything Three Dogs Ta...
# 116930  25005110      1  The Theory of Death (Peter Decker/Rina Lazarus...
# 116931  27037166      1                        Wolf Lake (Dave Gurney, #5)
#
#         ratings                                                url  \
# 0          4063  https://www.goodreads.com/book/show/32737635-t...
# 1       1076144  https://www.goodreads.com/book/show/22557272-t...
# 2       2429317  https://www.goodreads.com/book/show/11870085-t...
# 3       4899965  https://www.goodreads.com/book/show/2767052-th...
# 4         84357  https://www.goodreads.com/book/show/26893819-t...
# ...         ...                                                ...
# 116927      281  https://www.goodreads.com/book/show/22859574-t...
# 116928      869  https://www.goodreads.com/book/show/444734.Lat...
# 116929      578  https://www.goodreads.com/book/show/23507708-a...
# 116930       59  https://www.goodreads.com/book/show/25005110-t...
# 116931      268  https://www.goodreads.com/book/show/27037166-w...
#
#                                               cover_image  \
# 0       https://images.gr-assets.com/books/1477347638m...
# 1       https://images.gr-assets.com/books/1490903702m...
# 2       https://images.gr-assets.com/books/1360206420m...
# 3       https://images.gr-assets.com/books/1447303603m...
# 4       https://images.gr-assets.com/books/1492065338m...
# ...                                                   ...
# 116927  https://images.gr-assets.com/books/1423486499m...
# 116928  https://s.gr-assets.com/assets/nophoto/book/11...
# 116929  https://images.gr-assets.com/books/1423683984m...
# 116930  https://images.gr-assets.com/books/1432580315m...
# 116931  https://images.gr-assets.com/books/1445433652m...
#
#                                                 mod_title
# 0                       the most dangerous place on earth
# 1                                   the girl on the train
# 2                                  the fault in our stars
# 3                     the hunger games the hunger games 1
# 4                                               the girls
# ...                                                   ...
# 116927                       the year my mother came back
# 116928                                   later at the bar
# 116929  all dogs go to kevin everything three dogs tau...
# 116930    the theory of death peter deckerrina lazarus 23
# 116931                            wolf lake dave gurney 5
#
# [116932 rows x 7 columns]

# %%
# Creating a 'score' column 
# All the users who liked books that we also liked, how many of them also liked this book 

all_recs["score"] = all_recs["count"] * (all_recs["count"] / all_recs["ratings"])  # the more ratings a book has, the more populair that book is

# %%
# Sorting the scores of our recommendations

all_recs.sort_values("score", ascending=False).head(10)
# Out:
#        book_id  count                                         title  ratings  \
# 0     32737635    332             The Most Dangerous Place on Earth     4063
# 6763  34051963      8                                   Here We Lie       18
# 6549  29495703      8  Public Secrets (Artificial Intelligence, #1)       21
# 7889  32333338      7                                 Save the Date       19
# 9345  35297420      6                           She Regrets Nothing       17
# 3692  24909347     13             Obsidio (The Illuminae Files, #3)       82
# 326   32025142     62                                     White Fur     1973
# 124   30199414    100                                       Marlena     5324
# 6200  26856502      8                       Vengeful (Villains, #2)       35
# 4398  35099035     11                                    Red Clocks       67
#
#                                                     url  \
# 0     https://www.goodreads.com/book/show/32737635-t...
# 6763  https://www.goodreads.com/book/show/34051963-h...
# 6549  https://www.goodreads.com/book/show/29495703-p...
# 7889  https://www.goodreads.com/book/show/32333338-s...
# 9345  https://www.goodreads.com/book/show/35297420-s...
# 3692  https://www.goodreads.com/book/show/24909347-o...
# 326   https://www.goodreads.com/book/show/32025142-w...
# 124   https://www.goodreads.com/book/show/30199414-m...
# 6200  https://www.goodreads.com/book/show/26856502-v...
# 4398  https://www.goodreads.com/book/show/35099035-r...
#
#                                             cover_image  \
# 0     https://images.gr-assets.com/books/1477347638m...
# 6763  https://images.gr-assets.com/books/1499097971m...
# 6549  https://s.gr-assets.com/assets/nophoto/book/11...
# 7889  https://images.gr-assets.com/books/1510611507m...
# 9345  https://images.gr-assets.com/books/1510482237m...
# 3692  https://images.gr-assets.com/books/1501704611m...
# 326   https://images.gr-assets.com/books/1481903804m...
# 124   https://images.gr-assets.com/books/1491343350m...
# 6200  https://s.gr-assets.com/assets/nophoto/book/11...
# 4398  https://images.gr-assets.com/books/1494345016m...
#
#                                      mod_title      score
# 0            the most dangerous place on earth  27.128723
# 6763                               here we lie   3.555556
# 6549  public secrets artificial intelligence 1   3.047619
# 7889                             save the date   2.578947
# 9345                       she regrets nothing   2.117647
# 3692             obsidio the illuminae files 3   2.060976
# 326                                  white fur   1.948302
# 124                                    marlena   1.878287
# 6200                       vengeful villains 2   1.828571
# 4398                                red clocks   1.805970

# %%
all_recs[all_recs["count"] > 200].sort_values("score", ascending=False).head(10)
# Out:
#     book_id  count                                    title  ratings  \
# 0  32737635    332        The Most Dangerous Place on Earth     4063
# 4  26893819    206                                The Girls    84357
# 1  22557272    248                    The Girl on the Train  1076144
# 2  11870085    218                   The Fault in Our Stars  2429317
# 3   2767052    211  The Hunger Games (The Hunger Games, #1)  4899965
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/32737635-t...
# 4  https://www.goodreads.com/book/show/26893819-t...
# 1  https://www.goodreads.com/book/show/22557272-t...
# 2  https://www.goodreads.com/book/show/11870085-t...
# 3  https://www.goodreads.com/book/show/2767052-th...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1477347638m...
# 4  https://images.gr-assets.com/books/1492065338m...
# 1  https://images.gr-assets.com/books/1490903702m...
# 2  https://images.gr-assets.com/books/1360206420m...
# 3  https://images.gr-assets.com/books/1447303603m...
#
#                              mod_title      score
# 0    the most dangerous place on earth  27.128723
# 4                            the girls   0.503053
# 1                the girl on the train   0.057152
# 2               the fault in our stars   0.019563
# 3  the hunger games the hunger games 1   0.009086

# %%
# removing the books that have low recommendations 

popular_recs = all_recs[all_recs["count"] > 50].sort_values("score", ascending=False) # only books that are at least recommended 50 times

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)

# filtering out the books where the book_id is already in our book set - prevents us from seeing books that we have already read
popular_recs[~popular_recs["book_id"].isin(liked_books)].head(10).style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_40ab6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40ab6_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_40ab6_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_40ab6_level0_col2" class="col_heading level0 col2" >title</th>
#       <th id="T_40ab6_level0_col3" class="col_heading level0 col3" >ratings</th>
#       <th id="T_40ab6_level0_col4" class="col_heading level0 col4" >url</th>
#       <th id="T_40ab6_level0_col5" class="col_heading level0 col5" >cover_image</th>
#       <th id="T_40ab6_level0_col6" class="col_heading level0 col6" >mod_title</th>
#       <th id="T_40ab6_level0_col7" class="col_heading level0 col7" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40ab6_level0_row0" class="row_heading level0 row0" >326</th>
#       <td id="T_40ab6_row0_col0" class="data row0 col0" >32025142</td>
#       <td id="T_40ab6_row0_col1" class="data row0 col1" >62</td>
#       <td id="T_40ab6_row0_col2" class="data row0 col2" >White Fur</td>
#       <td id="T_40ab6_row0_col3" class="data row0 col3" >1973</td>
#       <td id="T_40ab6_row0_col4" class="data row0 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/32025142-white-fur">Goodreads</a></td>
#       <td id="T_40ab6_row0_col5" class="data row0 col5" ><a href="https://images.gr-assets.com/books/1481903804m/32025142.jpg"><img src="https://images.gr-assets.com/books/1481903804m/32025142.jpg" width=50></img></a></td>
#       <td id="T_40ab6_row0_col6" class="data row0 col6" >white fur</td>
#       <td id="T_40ab6_row0_col7" class="data row0 col7" >1.948302</td>
#     </tr>
#     <tr>
#       <th id="T_40ab6_level0_row1" class="row_heading level0 row1" >124</th>
#       <td id="T_40ab6_row1_col0" class="data row1 col0" >30199414</td>
#       <td id="T_40ab6_row1_col1" class="data row1 col1" >100</td>
#       <td id="T