# %% [markdown]
# # Reading in books we like

# %%
import pandas as pd

my_books = pd.read_csv("liked_books.csv", index_col=0)  # If you take a look at our file, our first column is an index column 
# so now we actually have 2 index colums, our real index and the index from within our file itself. 
# To fix this we set our file index column, which is column 0 to be our index column using "index_col = 0"

# %%
my_books
# Out:
#      user_id   book_id  rating  \
# 0         -1   2517439       5
# 1         -1    113576       5
# 2         -1     35100       5
# 3         -1    228221       5
# 5         -1  17662739       5
# 6         -1    356824       5
# 7         -1  12125412       5
# 8         -1    139069       5
# 10        -1     76680       5
# 11        -1      1898       5
# 12        -1   5096865       5
# 13        -1    228665       5
# 17        -1    437143       5
# 18        -1  18949861       5
# 19        -1   2913377       5
# 20        -1   1215032       5
# 21        -1    883438       5
# 22        -1   5578108       5
# 23        -1    128029       5
# 24        -1     77203       5
# 25        -1      5439       5
# 26        -1   1685995       5
# 27        -1   6448772       5
# 527       -1   8161140       1
# 528       -1     28187       1
# 531       -1  25659450       1
# 532       -1     82599       1
#
#                                                  title
# 0               The Forever War  (The Forever War, #1)
# 1    The Smartest Guys in the Room: The Amazing Ris...
# 2                                Battle Cry of Freedom
# 3                                  The Mask of Command
# 5           2001: A Space Odyssey  (Space Odyssey, #1)
# 6    India After Gandhi: The History of the World's...
# 7      The Lady or the Tiger?: and Other Logic Puzzles
# 8            Endurance: Shackleton's Incredible Voyage
# 10                        Foundation  (Foundation, #1)
# 11   Into Thin Air: A Personal Account of the Mount...
# 12                                       In Cold Blood
# 13       The Eye of the World  (The Wheel of Time, #1)
# 17                A Short History of Nearly Everything
# 18                                             Contact
# 19   The Name of the Wind  (The Kingkiller Chronicl...
# 20   The Wise Man's Fear  (The Kingkiller Chronicle...
# 21                                        East of Eden
# 22   From Colony to Superpower: U.S. Foreign Relati...
# 23                            A Thousand Splendid Suns
# 24                                     The Kite Runner
# 25                             Interpreter of Maladies
# 26                                     Dune  (Dune #1)
# 27   Quantum: Einstein, Bohr, and the Great Debate ...
# 527                                       On the Beach
# 528  The Lightning Thief  (Percy Jackson and the Ol...
# 531                                          Arkwright
# 532                                   Rabbits: A Novel

# %%
# Control if our book_id values are string/text data types 

if my_books['book_id'].dtypes == 'object':
    print('yes, they are')
else: 
    print('no, they are not')
# Out:
# no, they are not

# %%
# converting our book_id's to string values 

my_books['book_id'] = my_books['book_id'].astype(str)

# %% [markdown]
# # Finding similar users

# %%
# !head book_id_map.csv
# Out:
# book_id_csv,book_id
# 0,34684622
# 1,34536488
# 2,34017076
# 3,71730
# 4,30422361
# 5,33503613
# 6,33517540
# 7,34467031
# 8,6383669

# %%
# As in the recommendation file, we first make a dictionary which maps (key->value) 
# the file containing the id's of the books with file that contains information about the id's/books

csv_book_mapping = {}

with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",") 
        csv_book_mapping[csv_id] = book_id

# %%
# Making a unique list containing our liked books

book_set = set(my_books["book_id"])

# %%
# !head goodreads_interactions.csv
# Out:
# user_id,book_id,is_read,rating,is_reviewed
# 0,948,1,5,0
# 0,947,1,5,1
# 0,946,1,5,0
# 0,945,1,5,0
# 0,944,1,5,0
# 0,943,1,5,0
# 0,942,1,5,0
# 0,941,1,5,0
# 0,940,1,5,0

# %% [markdown]
# # Creating a dictionary

# %%
overlap_users = {}

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")  # For every line we are splitting every comma as you can see above and we only take the "user_id", "book_id" and the "rating", I don't care about the other 2 
        
        book_id = csv_book_mapping.get(csv_id) # Using .get method returns "None" if there is a specific key not available in stead of raising a Keyerror

        
        if book_id in book_set:
            if user_id not in overlap_users: # Keeping count of how many times a user has liked a book tht we have liked 
                overlap_users[user_id] = 1
            else:
                overlap_users[user_id] += 1 # Returns a dictionary with other users as key and their values the count described above

# %%
len(overlap_users)
# Out:
# 316341

# %%
# Only finding users that have liked the same books as us 
# Only showing the users who have read at least 20% of the books that we have read 

filtered_overlap_users = set([u for u in overlap_users if overlap_users[u] > my_books.shape[0]/5])

# %%
len(filtered_overlap_users)
# Out:
# 1258

# %% [markdown]
# # Finding similar users book ratings

# %%
# For every user that has read a specific amount of books that we have read (cell above) 
# we will create a list with all the books they have read 

interactions_list = []

with open ("goodreads_interactions.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")

        if user_id in filtered_overlap_users:
            book_id = csv_book_mapping[csv_id]
            interactions_list.append([user_id, csv_id, rating])

# %% [markdown]
# # Creating a user/book matrix

# %%
len(interactions_list)
# Out:
# 5638701

# %%
interactions_list[0]
# Out:
# ['282', '1064', '4']

# %%
# Turning our list into a dataframe and naming the columns

interactions = pd.DataFrame(interactions_list, columns=["user_id", "book_id", "rating"])

# %%
interactions
# Out:
#         user_id book_id rating
# 0           282    1064      4
# 1           282     739      4
# 2           282    7220      4
# 3           282    1041      3
# 4           282     787      4
# ...         ...     ...    ...
# 5638696  804100  145214      0
# 5638697  804100     126      0
# 5638698  804100    8250      0
# 5638699  804100   17400      0
# 5638700  804100  754399      5
#
# [5638701 rows x 3 columns]

# %%
# Putting our ratings into the list with the ratings of everybody else 

interactions = pd.concat([my_books[["user_id", "book_id", "rating"]], interactions])

# pd.concat is a function in the pandas library that concatenates
# (combines) multiple DataFrames along a specified axis.

# %%
interactions
# Out:
#         user_id   book_id rating
# 0            -1   2517439      5
# 1            -1    113576      5
# 2            -1     35100      5
# 3            -1    228221      5
# 5            -1  17662739      5
# ...         ...       ...    ...
# 5638696  804100    145214      0
# 5638697  804100       126      0
# 5638698  804100      8250      0
# 5638699  804100     17400      0
# 5638700  804100    754399      5
#
# [5638728 rows x 3 columns]

# %%
# Making sure we have the right data types 

# Our book_id's and user_id's are strings in our json file so we want to make sure we have the same dtypes (str)
# to be able to allign properly between files, lists, ... (our ratings are numbers) 

interactions["book_id"] = interactions["book_id"].astype(str)
interactions["user_id"] = interactions["user_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"])

# %%
# Giving each "user_id" a unique value

interactions["user_id"].unique()
# Out:
# array(['-1', '282', '874', ..., '442043', '712588', '804100'],
#       dtype=object)

# %%
# Converting al the values/user_id's that are the same to the same category 
# (creates a number that corresponds to a specific user_id) 

interactions["user_index"] = interactions["user_id"].astype("category").cat.codes

# %%
interactions["user_index"].unique()
# Out:
# array([   0,  555, 1216, ..., 1054, 1143, 1183], dtype=int16)

# %%
interactions["book_index"] = interactions["book_id"].astype("category").cat.codes

# .cat.codes converts categorical values into numerical values to make the data more compact en better to act on

# %%
len(interactions["book_index"].unique())
# Out:
# 802886

# %%
len(interactions["user_index"].unique())
# Out:
# 1259

# %% [markdown]
# # Creating a sparse matrix

# %% [markdown]
# Because of the fact that we are working with a lot of data were not every position/value is filled we are using a sparse matrix in stead of a dense matrix

# %%
from scipy.sparse import coo_matrix

# Arguments coo_matrix((wanted data in the cells, row positions, column positions))

ratings_mat_coo = coo_matrix((interactions["rating"], (interactions["user_index"], interactions["book_index"])))

# %%
ratings_mat_coo
# Out:
# <1259x802886 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5638728 stored elements in COOrdinate format>

# %%
ratings_mat = ratings_mat_coo.tocsr()

# Is used to convert a sparse matrix to a compressed sparse row format ('csr'),
# in order to optimize memory usage and enable better/efficient matrix operations.
# the csr format provides faster acces to row-based operations -> faster (numerical) computations and algorithms

# %% [markdown]
# # Finding users similar to us

# %%
interactions[interactions["user_id"] == "-1"].head()
# Out:
#   user_id   book_id  rating  user_index  book_index
# 0      -1   2517439       5           0      337556
# 1      -1    113576       5           0       57909
# 2      -1     35100       5           0      413689
# 3      -1    228221       5           0      317541
# 5      -1  17662739       5           0      242200

# %%
# Setting our own user_id index to a seperate index 
# row 0 in the matrix will be our book ratings

my_index = 0

# %%
# cosine similarity finds the similarity between 2 rows in our matrix, 
# i.e. how similar their(other readers) readings are compared to ours

from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(ratings_mat[my_index,:], ratings_mat).flatten()

# %%
similarity[0]
# Out:
# 0.9999999999999999

# %%
# Finding the indices/users who are the most similar to us 

import numpy as np 

indices = np.argpartition(similarity, -15)[-15:] # argpartitions finds the positions of the highest values

# %%
indices
# Out:
# array([ 845,  655,  656,  894, 1243,  957,  167, 1100,  588,  951,  320,
#          32,  161,  274,    0])

# %%
# Searching for their user id's 

similar_users = interactions[interactions["user_index"].isin(indices)].copy() # finds all the rows where the "user_index" is in our indices

# %%
similar_users
# Out:
#         user_id   book_id  rating  user_index  book_index
# 0            -1   2517439       5           0      337556
# 1            -1    113576       5           0       57909
# 2            -1     35100       5           0      413689
# 3            -1    228221       5           0      317541
# 5            -1  17662739       5           0      242200
# ...         ...       ...     ...         ...         ...
# 5230521  416683    599649       0         957      587368
# 5230522  416683     67654       0         957      633909
# 5230523  416683    599651       0         957      587370
# 5230524  416683    921757       5         957      768366
# 5230525  416683    906583       0         957      761272
#
# [64242 rows x 5 columns]

# %%
# Taking ourselves out of the list 

similar_users = similar_users[similar_users["user_id"]!="-1"] # Only proceeding with the user_id's that aren't ours ("-1")

# %%
similar_users
# Out:
#         user_id book_id  rating  user_index  book_index
# 521343    41530     706       3         951      650295
# 521344    41530  317819       3         951      387638
# 521345    41530   30694       3         951      381295
# 521346    41530    7390       4         951      669590
# 521347    41530    7332       4         951      666071
# ...         ...     ...     ...         ...         ...
# 5230521  416683  599649       0         957      587368
# 5230522  416683   67654       0         957      633909
# 5230523  416683  599651       0         957      587370
# 5230524  416683  921757       5         957      768366
# 5230525  416683  906583       0         957      761272
#
# [64215 rows x 5 columns]

# %% [markdown]
# # Creating book recommendations

# %%
# Figuring out how many times each book appeared in the recommendations 

book_recs = similar_users.groupby("book_id").rating.agg(['count', 'mean']) # .agg here takes the average rating out of all the ratings it has received from users/readers

# %%
book_recs
# Out:
#          count      mean
# book_id
# 0            1  0.000000
# 10           7  1.428571
# 100          7  1.285714
# 1000         9  2.111111
# 1000290      1  0.000000
# ...        ...       ...
# 99976        1  0.000000
# 99983        1  4.000000
# 99987        1  0.000000
# 99993        2  0.000000
# 99996        3  3.000000
#
# [48240 rows x 2 columns]

# %%
# Reading in our book_titles again and making sure they are of the right dtype 

books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

# %%
# Merging our 2 datasets to get our book_titles, ... into our recommendations 

book_recs_merged = book_recs.merge(books_titles, how="inner", on="book_id")

# %%
book_recs_merged
# Out:
#       book_id  count      mean  \
# 0          10      7  1.428571
# 1         100      7  1.285714
# 2        1000      9  2.111111
# 3      100052      1  0.000000
# 4      100060      1  0.000000
# ...       ...    ...       ...
# 14323   99943      1  4.000000
# 14324   99945      1  0.000000
# 14325  999660      1  0.000000
# 14326   99983      1  4.000000
# 14327   99993      2  0.000000
#
#                                                  title_x  ratings_x  \
# 0           Harry Potter Collection (Harry Potter, #1-6)      25245
# 1                               Simply Beautiful Beading         75
# 2      Millionaire Women Next Door: The Many Journeys...        460
# 3                                             Austerlitz        137
# 4      When Godly People Do Ungodly Things: Finding A...       1201
# ...                                                  ...        ...
# 14323                                  The Bhagavad-Gita         16
# 14324                   Bhagavad Gita: A New Translation        965
# 14325                                  The Drowned World         58
# 14326  The Best American Science and Nature Writing 2001         68
# 14327  The Best American Science and Nature Writing 2002         79
#
#                                                    url_x  \
# 0      https://www.goodreads.com/book/show/10.Harry_P...
# 1      https://www.goodreads.com/book/show/100.Simply...
# 2      https://www.goodreads.com/book/show/1000.Milli...
# 3      https://www.goodreads.com/book/show/100052.Aus...
# 4      https://www.goodreads.com/book/show/100060.Whe...
# ...                                                  ...
# 14323  https://www.goodreads.com/book/show/99943.The_...
# 14324  https://www.goodreads.com/book/show/99945.Bhag...
# 14325  https://www.goodreads.com/book/show/999660.The...
# 14326  https://www.goodreads.com/book/show/99983.The_...
# 14327  https://www.goodreads.com/book/show/99993.The_...
#
#                                            cover_image_x  \
# 0      https://images.gr-assets.com/books/1328867351m...
# 1      https://s.gr-assets.com/assets/nophoto/book/11...
# 2      https://s.gr-assets.com/assets/nophoto/book/11...
# 3      https://s.gr-assets.com/assets/nophoto/book/11...
# 4      https://s.gr-assets.com/assets/nophoto/book/11...
# ...                                                  ...
# 14323  https://s.gr-assets.com/assets/nophoto/book/11...
# 14324  https://images.gr-assets.com/books/1320542459m...
# 14325  https://images.gr-assets.com/books/1330786609m...
# 14326  https://s.gr-assets.com/assets/nophoto/book/11...
# 14327  https://images.gr-assets.com/books/1382946502m...
#
#                                              mod_title_x  \
# 0                harry potter collection harry potter 16
# 1                               simply beautiful beading
# 2      millionaire women next door the many journeys ...
# 3                                             austerlitz
# 4      when godly people do ungodly things finding au...
# ...                                                  ...
# 14323                                   the bhagavadgita
# 14324                    bhagavad gita a new translation
# 14325                                  the drowned world
# 14326  the best american science and nature writing 2001
# 14327  the best american science and nature writing 2002
#
#                                                  title_y  ratings_y  \
# 0           Harry Potter Collection (Harry Potter, #1-6)      25245
# 1                               Simply Beautiful Beading         75
# 2      Millionaire Women Next Door: The Many Journeys...        460
# 3                                             Austerlitz        137
# 4      When Godly People Do Ungodly Things: Finding A...       1201
# ...                                                  ...        ...
# 14323                                  The Bhagavad-Gita         16
# 14324                   Bhagavad Gita: A New Translation        965
# 14325                                  The Drowned World         58
# 14326  The Best American Science and Nature Writing 2001         68
# 14327  The Best American Science and Nature Writing 2002         79
#
#                                                    url_y  \
# 0      https://www.goodreads.com/book/show/10.Harry_P...
# 1      https://www.goodreads.com/book/show/100.Simply...
# 2      https://www.goodreads.com/book/show/1000.Milli...
# 3      https://www.goodreads.com/book/show/100052.Aus...
# 4      https://www.goodreads.com/book/show/100060.Whe...
# ...                                                  ...
# 14323  https://www.goodreads.com/book/show/99943.The_...
# 14324  https://www.goodreads.com/book/show/99945.Bhag...
# 14325  https://www.goodreads.com/book/show/999660.The...
# 14326  https://www.goodreads.com/book/show/99983.The_...
# 14327  https://www.goodreads.com/book/show/99993.The_...
#
#                                            cover_image_y  \
# 0      https://images.gr-assets.com/books/1328867351m...
# 1      https://s.gr-assets.com/assets/nophoto/book/11...
# 2      https://s.gr-assets.com/assets/nophoto/book/11...
# 3      https://s.gr-assets.com/assets/nophoto/book/11...
# 4      https://s.gr-assets.com/assets/nophoto/book/11...
# ...                                                  ...
# 14323  https://s.gr-assets.com/assets/nophoto/book/11...
# 14324  https://images.gr-assets.com/books/1320542459m...
# 14325  https://images.gr-assets.com/books/1330786609m...
# 14326  https://s.gr-assets.com/assets/nophoto/book/11...
# 14327  https://images.gr-assets.com/books/1382946502m...
#
#                                              mod_title_y
# 0                harry potter collection harry potter 16
# 1                               simply beautiful beading
# 2      millionaire women next door the many journeys ...
# 3                                             austerlitz
# 4      when godly people do ungodly things finding au...
# ...                                                  ...
# 14323                                   the bhagavadgita
# 14324                    bhagavad gita a new translation
# 14325                                  the drowned world
# 14326  the best american science and nature writing 2001
# 14327  the best american science and nature writing 2002
#
# [14328 rows x 13 columns]

# %% [markdown]
# # Ranking our book recommendations

# %%
# Creating a count for how many times the book appeared to people like us (same interests), 
# relative to how many times it had appeared to other people. 
# We want only the books that were populair recommended to people like us, but not to other users with other interests

book_recs["adjusted_count"] = book_recs["count"] * (book_recs["count"] / book_recs["ratings"]) # trying to find the books that are specific to us

# %%
# Creating a score, how much we might like a specific book 

book_recs["score"] = book_recs["mean"] * book_recs["adjusted_count"]

# %%
# Taking out any books we have already read (method 1) 

book_recs = book_recs[~book_recs["book_id"].isin(my_books["book_id"])]

# %%
# Beacuse some books have duplicates -> data problem (method 2)
# Converting the titles of the books into the same (our) format 

my_books["mod_title"] = my_books["title"].str.replace("[^a-zA-Z0-9 ]", "", regex=True).str.lower()

# %%
# Replacing any sequences of spaces by just 1 space 

my_books["mod_title"] = my_books["mod_title"].str.replace("\s+", " ", regex=True)

# %%
# Method 2, now deleting these duplicates out of our recommendations 

book_recs = book_recs[~book_recs["mod_title"].isin(my_books["mod_title"])]

# %%
# removing anything that appeared less then 2 

book_recs = book_recs[book_recs["count"]>2] # Only proceeding with the books that appeared more then 2x

# %%
# only finding/showing books where our mean(average) rating is 4 or higher 

book_recs = book_recs[book_recs["mean"]>=4]

# %%
top_recs = book_recs.sort_values("mean", ascending=False)

# %% [markdown]
# # Improving the display of the book as we did in the "Search" notebook

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val) # Gives us clickable links to the books

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val) # Renders/shows the cover image 

top_recs.style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_a3d29">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3d29_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_a3d29_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_a3d29_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_a3d29_level0_col3" class="col_heading level0 col3" >title</th>
#       <th id="T_a3d29_level0_col4" class="col_heading level0 col4" >ratings</th>
#       <th id="T_a3d29_level0_col5" class="col_heading level0 col5" >url</th>
#       <th id="T_a3d29_level0_col6" class="col_heading level0 col6" >cover_image</th>
#       <th id="T_a3d29_level0_col7" class="col_heading level0 col7" >mod_title</th>
#       <th id="T_a3d29_level0_col8" class="col_heading level0 col8" >adjusted_count</th>
#       <th id="T_a3d29_level0_col9" class="col_heading level0 col9" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3d29_level0_row0" class="row_heading level0 row0" >5624</th>
#       <td id="T_a3d29_row0_col0" class="data row0 col0" >24929</td>
#       <td id="T_a3d29_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_a3d29_row0_col2" class="data row0 col2" >4.666667</td>
#       <td id="T_a3d29_row0_col3" class="data row0 col3" >Lost</td>
#       <td id="T_a3d29_row0_col4" class="data row0 col4" >12607</td>
#       <td id="T_a3d29_row0_col5" class="data row0 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/24929.Lost">Goodreads</a></td>
#       <td id="T_a3d29_row0_col6" class="data row0 col6" ><a href="https://images.gr-assets.com/books/1407711681m/24929.jpg"><img src="https://images.gr-assets.com/books/1407711681m/24929.jpg" width=50></img></a></td>
#       <td id="T_a3d29_row0_col7" class="data row0 col7" >lost</td>
#       <td id="T_a3d29_row0_col8" class="data row0 col8" >0.000714</td>
#       <td id="T_a3d29_row0_col9" class="data row0 col9" >0.003331</td>
#     </tr>
#     <tr>
#       <th id="T_a3d29_level0_row1" class="row_heading level0 row1" >12486</th>
#       <td id="T_a3d29_row1_col0" class="data row1 col0" >74909</td>
#       <td id="T_a3d29_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_a3d29_row1_col2" class="data row1 col2" >4.666667</td>
#       <td id="T_a3d29_row1_col3" class="data row1 col3" >How Wal-Mart Is Destroying America (And the World): And What You Can Do about It</td>
#       <td id="T_a3d29_row1_col4" class="data row1 col4" >139</td>
#       <td id="T_a3d29_row1_col5" class="data row1 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/74909.How_Wal_Mart_Is_Destroying_America_And_the_World_">Goodreads</a></td>
#       <td id="T_a3d29_row1_col6" class="data row1 col6" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#       <td id="T_a3d29_row1_col7" class="data row1 col7" >how walmart is destroying america and the world and what you can do about it</td>
#       <td id="T_a3d29_row1_col8" class="data row1 col8" >0.064748</td>
#       <td id="T_a3d29_row1_col9" class="data row1 col9" >0.302158</td>
#     </tr>
#     <tr>
#       <th id="T_a3d29_level0_row2" class="row_heading level0 row2" >7548</th>
#       <td id="T_a3d29_row2_col0" class="data row2 col0" >35727</td>
#       <td id="T_a3d29_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_a3d29_row2_col2" class="data row2 col2" >4.666667</td>
#       <td id="T_a3d29_row2_col3" class="data row2 col3" >The Laws of Spirit: A Tale of Transformation</td>
#       <td id="T_a3d29_row2_col4" class="data row2 col4" >753</td>
#       <td id="T_a3d29_row2_col5" class="data row2 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/35727.The_Laws_of_Spirit">Goodreads</a></td>
#       <td id="T_a3d29_row2_col6" class="data row2 col6" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#       <td id="T_a3d29_row2_col7" class="data row2 col7" >the laws of spirit a tale of transformation</td>
#       <td id="T_a3d29_row2_col8" class="data row2 col8" >0.011952</td>
#       <td id="T_a3d29_row2_col9" class="data row2 col9" >0.055777</td>
#     </tr>
#     <tr>
#       <th id="T_a3d29_level0_row3" class="row_heading level0 row3" >4125</th>
#       <td id="T_a3d29_row3_col0" class="data row3 col0" >18950</td>
#       <td id="T_a3d29_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_a3d29_row3_col2" class="data row3 col2" >4.666667</td>
#       <td id="T_a3d29_row3_col3" class="data row3 col3" >The Best of Cordwainer Smith</td>
#       <td id="T_a3d29_row3_col4" class="data row3 col4" >242</td>
#       <td id="T_a3d29_row3_col5" class="data row3 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/18950.The_Best_of_Cordwainer_Smith">Goodreads</a></td>
#       <td id="T_a3d29_row3_col6" class="data row3 col6" ><a href="https://images.gr-assets.com/books/1330823999m/18950.jpg"><img src="https://images.gr-assets.com/books/1330823999m/18950.jpg" width=50></img></a></td>
#       <td id="T_a3d29_row3_col7" class="data row3 col7" >the best of cordwainer smith</td>
#       <td id="T_a3d29_row3_col8" class="data row3 col8" >0.037190</td>
#       <td id="T_a3d29_row3_col9" class="data row3 col9" >0.173554</td>
#     </tr>
#     <tr>
#       <th id="T_a3d29_level0_row4" class="row_heading level0 row4" >5658</th>
#       <td id="T_a3d29_row4_col0" class="data row4 col0" >25032</td>
#       <td id="T_a3d29_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_a3d29_row4_col2" class="data row4 col2" >4.333333</td>
#       <td id="T_a3d29_row4_col3" class="data row4 col3" >Classical Drawing Atelier: A Contemporary Guide to Traditional Studio Practice</td>
#       <td id="T_a3d29_row4_col4" class="data row4 col4" >3148</td>
#       <td id="T_a3d29_row4_col5" class="data row4 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/25032.Classical_Drawing_Atelier">Goodreads</a></td>
#       <td id="T_a3d29_row4_col6" class="data row4 col6" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#       <td id="T_a3d29_row4_col7" class="data row4 col7" >classical drawing atelier a contemporary guide to traditional studio practice</td>
#       <td id="T_a3d29_row4_col8" class="data row4 col8" >0.002859</td>
#       <td id="T_a3d29_row4_col9" class="data row4 col9" >0.012389</td>
#     </tr>
#     <tr>
#       <th id="T_a3d29_level0_row5" class="row_heading level0 row5" >13561</th>
#       <td id="T_a3d29_row5_col0" class="data row5 col0" >87992</td>
#       <td id="T_a3d29_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_a3d29_row5_col2" class="data row5 col2" >4.333333</td>
#       <td id="T_a3d29_row5_col3" class="data row5 col3" >Lucky Girls</td>
#       <td id="T_a3d29_row5_col4" class="data row5 col4" >800</td>
#       <td id="T_a3d29_row5_col5" class="data row5 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/87992.Lucky_Girls">Goodreads</a></td>
#       <td id="T_a3d29_row5_col6" class="data row5 col6" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#       <td id="T_a3d29_row5_col7" class="data row5 col7" >lucky girls</td>
#       <td id="T_a3d29_row5_col8" class="data row5 col8" >0.011250</td>
#       <td id="T_a3d29_row5_col9" class="data row5 col9" >0.048750</td>
#     </tr>
#     <tr>
#       <th id="T_a3d29_level0_row6" class="row_heading level0 row6" >2600</th>
#       <td id="T_a3d29_row6_col0" class="data row6 col0" >14948</td>
#       <td id="T_a3d29_row6_col1

# %% [markdown]
# # Tweakable parameters

# %%
# Filtered_overlap_users 
# Screaping goodreas for more data 
# indices -> Taking more recoms in stead of 15 
# Adjusting how to
